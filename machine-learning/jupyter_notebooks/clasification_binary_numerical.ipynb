# %%
import pandas as pd

# %%
data = pd.read_csv('datasets/gender_voice_dataset.csv')
data.sample(10)
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 1754  0.181512  0.032579  0.181155  0.165722  0.195853  0.030131  2.897037
# 1648  0.151097  0.086332  0.183914  0.061055  0.221197  0.160143  1.659775
# 2648  0.200862  0.036944  0.201336  0.179882  0.222790  0.042908  2.325588
# 174   0.188815  0.070485  0.163711  0.134110  0.257648  0.123538  2.198545
# 613   0.155246  0.072312  0.170056  0.101243  0.214825  0.113582  2.011780
# 2580  0.235297  0.030404  0.237711  0.220350  0.255517  0.035167  1.745699
# 45    0.148281  0.068117  0.129893  0.094868  0.200343  0.105475  3.268475
# 2522  0.203236  0.038226  0.195420  0.182460  0.231912  0.049452  2.764458
# 2941  0.205945  0.036712  0.204133  0.181391  0.235062  0.053671  1.492789
# 381   0.189749  0.068091  0.214704  0.128011  0.249750  0.121739  1.631487
#
#            kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 1754  12.767946  0.826029  0.196993  ...  0.181512  0.178054  0.085561
# 1648   6.155128  0.958604  0.710824  ...  0.151097  0.187887  0.041995
# 2648  10.309561  0.870005  0.213134  ...  0.200862  0.149295  0.047904
# 174   10.783439  0.895111  0.333553  ...  0.188815  0.090939  0.015702
# 613    8.263244  0.960913  0.705632  ...  0.155246  0.099438  0.019394
# 2580   5.142853  0.826122  0.129338  ...  0.235297  0.178994  0.047431
# 45    22.896445  0.942626  0.635853  ...  0.148281  0.097532  0.015810
# 2522  13.374830  0.870564  0.240827  ...  0.203236  0.168331  0.046921
# 2941   4.796759  0.888007  0.208745  ...  0.205945  0.168331  0.018957
# 381    5.466889  0.923294  0.521869  ...  0.189749  0.116147  0.024060
#
#         maxfun   meandom    mindom     maxdom    dfrange   modindx   label
# 1754  0.271186  0.432155  0.164062   4.406250   4.242188  0.124105  female
# 1648  0.242424  0.298234  0.015625   0.851562   0.835938  0.244326  female
# 2648  0.274286  1.196514  0.187500   7.945312   7.757812  0.112926  female
# 174   0.262295  0.118719  0.007812   0.398438   0.390625  0.240000    male
# 613   0.197531  0.333079  0.015625   5.367188   5.351562  0.067153    male
# 2580  0.279070  2.515443  0.023438  10.710938  10.687500  0.158606  female
# 45    0.275862  0.715745  0.007812   5.226562   5.218750  0.139222    male
# 2522  0.277457  1.474051  0.023438   8.039062   8.015625  0.136739  female
# 2941  0.258065  0.855208  0.007812   5.023438   5.015625  0.181854  female
# 381   0.231884  0.752232  0.140625   3.640625   3.500000  0.257254    male
#
# [10 rows x 21 columns]

# %%
data.shape
# Out:
# (3168, 21)

# %%
data.describe()
# Out:
#           meanfreq           sd       median          Q25          Q75  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.180907     0.057126     0.185621     0.140456     0.224765
# std       0.029918     0.016652     0.036360     0.048680     0.023639
# min       0.039363     0.018363     0.010975     0.000229     0.042946
# 25%       0.163662     0.041954     0.169593     0.111087     0.208747
# 50%       0.184838     0.059155     0.190032     0.140286     0.225684
# 75%       0.199146     0.067020     0.210618     0.175939     0.243660
# max       0.251124     0.115273     0.261224     0.247347     0.273469
#
#                IQR         skew         kurt       sp.ent          sfm  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.084309     3.140168    36.568461     0.895127     0.408216
# std       0.042783     4.240529   134.928661     0.044980     0.177521
# min       0.014558     0.141735     2.068455     0.738651     0.036876
# 25%       0.042560     1.649569     5.669547     0.861811     0.258041
# 50%       0.094280     2.197101     8.318463     0.901767     0.396335
# 75%       0.114175     2.931694    13.648905     0.928713     0.533676
# max       0.252225    34.725453  1309.612887     0.981997     0.842936
#
#               mode     centroid      meanfun       minfun       maxfun  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.165282     0.180907     0.142807     0.036802     0.258842
# std       0.077203     0.029918     0.032304     0.019220     0.030077
# min       0.000000     0.039363     0.055565     0.009775     0.103093
# 25%       0.118016     0.163662     0.116998     0.018223     0.253968
# 50%       0.186599     0.184838     0.140519     0.046110     0.271186
# 75%       0.221104     0.199146     0.169581     0.047904     0.277457
# max       0.280000     0.251124     0.237636     0.204082     0.279114
#
#            meandom       mindom       maxdom      dfrange      modindx
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.829211     0.052647     5.047277     4.994630     0.173752
# std       0.525205     0.063299     3.521157     3.520039     0.119454
# min       0.007812     0.004883     0.007812     0.000000     0.000000
# 25%       0.419828     0.007812     2.070312     2.044922     0.099766
# 50%       0.765795     0.023438     4.992188     4.945312     0.139357
# 75%       1.177166     0.070312     7.007812     6.992188     0.209183
# max       2.957682     0.458984    21.867188    21.843750     0.932374

# %%
from sklearn.preprocessing import LabelEncoder
labelEncoder = LabelEncoder()
data['label'] = labelEncoder.fit_transform(data['label'].astype(str))
data.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402905  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# 0  0.275862  0.007812  0.007812  0.007812  0.000000  0.000000      1
# 1  0.250000  0.009014  0.007812  0.054688  0.046875  0.052632      1
# 2  0.271186  0.007990  0.007812  0.015625  0.007812  0.046512      1
# 3  0.250000  0.201497  0.007812  0.562500  0.554688  0.247119      1
# 4  0.266667  0.712812  0.007812  5.484375  5.476562  0.208274      1
#
# [5 rows x 21 columns]

# %%
data.boxplot(column='meanfreq', by='label')
# Out:
# <Axes: title={'center': 'meanfreq'}, xlabel='label'>

# %%
from sklearn.model_selection import train_test_split
X = data.drop('label', axis=1)
Y = data['label']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
x_train.shape, x_test.shape
# Out:
# ((2534, 20), (634, 20))

# %%
from sklearn.linear_model import LogisticRegression
logistic_model = LogisticRegression(penalty='l2', solver='liblinear')
logistic_model.fit(x_train, y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
y_pred = logistic_model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
confustion_matrix = confusion_matrix(y_test, y_pred)
print(confustion_matrix)
# Out:
# [[257  44]
#  [ 10 323]]

# %%
print("Training Score: ", logistic_model.score(x_train, y_train))
# Out:
# Training Score:  0.909629044988161

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
acc = accuracy_score(y_test, y_pred)
pre = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)
print("Accuracy: ", acc)
print("Precision: ", pre)
print("Recall: ", rec)
# Out:
# Accuracy:  0.9148264984227129
# Precision:  0.8801089918256131
# Recall:  0.96996996996997
